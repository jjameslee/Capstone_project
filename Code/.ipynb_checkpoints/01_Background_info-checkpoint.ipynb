# %% [markdown]
# # LAFD Response Time

# %% [markdown]
# ## Background:
#
# Back in early 2012, The Los Angeles Fire Department admitted to the [Los Angeles Times](https://latimesblogs.latimes.com/lanow/2012/03/la-fire-department-admits-exaggerating-response-times.html) that they exaggerated the data to make it appear that firefighters were responding to emergencies quicker than they actually were. The false data reported that in 2008 the department responded to emergencies within five minutes about 86 percent of the time. It turns out the LAFD categorized 6 minute responses the same as 5 minute responses. Apparently the corrected data shows that the department actually met the five-minute benchmark only 64 percent of the time in 2008. In the LA Times report mentioned above, it states the "Federal guidelines call for first responders to arrive on scene in under five minutes 90% of the time."
#
# According to the city wide response metrics from January to March of 2019, found on the [LAFD's website](https://www.lafd.org/fsla/stations-map), the average EMS (emergency medical service) response time is 6 minutes 36 seconds.

# %% [markdown]
# ## Problem Statement:
#
# We will use two datas from the [Los Angeles City website](https://data.lacity.org/), LAFD's response metric and Census Data of Los Angeles neighborhoods, in order to explore the emergency metrics and census data for each of the 97 LA neighborhood councils. The main objectives for this project are listed as follows:
#
# **1) We want to analyze if certain neighborhood councils (location/region) within the Los Angeles County have any affect on the time it takes for the LAFD respondents to arrive at the scene. In this project we strive to investigate whether certain factors such as, the poverty rate or a majority ethnic group of a location in LA have any correlation to the average response time from the LAFD.**
#
# **2) We will build a regression model to predict the response time of the LAFD when it comes to EMS reports for a particular location in the county of Los Angeles. Model performance will be guided by RMSE, and the model should improve the baseline by as much as it can.**

# %% [markdown]
# ### Dataset:
#
# [Source](https://data.lacity.org/A-Safe-City/LAFD-Response-Metrics-Raw-Data/n44u-wxe4)
# * LAFD Response Metrics - Raw Data
#     - Data last updated in April 8, 2019
#
# [Source](https://data.lacity.org/A-Safe-City/All-Stations-Response-Metrics/kszm-sdw4)
# * Archived response Time metrics for all LAFD stations
#     - Contains all stations response metrics from 2011 to 2017
#
# [Source](https://data.lacity.org/A-Safe-City/Fire-Stations/sfzi-8n8k)
# * LA County Fire Station locations (geo-spatial data)
#     - Data last updated in November 2016
#
# [Source](https://data.lacity.org/A-Livable-and-Sustainable-City/Census-Data-by-Neighborhood-Council/nwj3-ufba)
# * Census 2010 population/demographic data approximated from block groups to 97 LA Neighborhood Councils
#     - Data last updated in April 2018
#
# [Source](https://data.lacity.org/A-Well-Run-City/Neighborhood-Councils-Certified-/fu65-dz2f)
# * Neighborhood Councils -Certified (geo-spatial data)
#     - Official Certified Neighborhood Council boundaries in the City of Los Angeles created and maintained by the Bureau of Engineering /       GIS Mapping Division.
#     - Data last updated in November 2017

# %% [markdown]
# _____

# %% [markdown]
# Inspired by this [DataCamp blog](https://www.datacamp.com/community/tutorials/geospatial-data-python)
# for geospatial data tutorial.
#
# The US map geospatial data originates from this [website](http://eric.clst.org/tech/usgeojson/), which contains boundary maps of the entire country, state, and county of the U.S. For the scope of this project, we will use the US Counties data (5m, GeoJSON file).

# %%
import pandas as pd
import geopandas
import numpy as np
from shapely.geometry import Point
import missingno as msn
import seaborn as sns
import pickle
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# We will start off by displaying which of the fire-station departments we will incorporate throughout this project as well as its' locations.

# %%
fire = geopandas.read_file('./data/Fire Stations.geojson')
print(fire.shape)
fire.head()
# Out:
# (106, 14)
#             x_coord      zip           y_coord suff_dir fs_cd  \
# 0  6468261.23133615  90029.0  1853003.78836346             52
# 1   6474895.4099969  90004.0  1850557.76471221              6
# 2  6434222.00610764  90064.0  1838657.47355221             92
# 3   6473368.7929714  90044.0  1811143.98888113             57
# 4  6407434.92713597  91406.0  1892973.60442105            100
#
#            shp_addr sttype   stname    hseno               address pref_dir  \
# 0   Fire Station 52    AVE  MELROSE   4957.0     4957 MELROSE AVE.
# 1    Fire Station 6    AVE   VIRGIL    326.0    326 N. VIRGIL AVE.        N
# 2   Fire Station 92   BLVD     PICO  10556.0    10556 W. PICO BLVD        W
# 3   Fire Station 57    AVE  VERMONT   7800.0  7800 S. VERMONT AVE.        S
# 4  Fire Station 100    AVE   LOUISE   6751.0       6751 LOUISE AVE
#
#   deptname unitdesc                                      geometry
# 0     FIRE           POINT (-118.3084747856537 34.08375012794097)
# ...

# %% [markdown]
# We need to make sure the number listed in the fire-station column ('fs_cd') in this geospatial data aligns with the number in the fire-station column of all our other dataset that we will be using throughout this project. After reading the data dictionary and plotting out the fire-station location and Neighborhood Council regions, we will move forth with the assumption that it is related.
#
# Shown below is a dictionary that pairs a neighborhood council in the LA County with its' respective fire-station department that is within its' boundaries. Many have 1 fire-station, others may have more than 1 depending on the size of the N.C area.

# %%
dict_nc_fire_station =[ 
{'ARLETA NC' : 7},
{'BEL AIR-BEVERLY CREST NC' : 108},
{'BOYLE HEIGHTS NC' : 2},
{'BOYLE HEIGHTS NC' : 25},
{'CANOGA PARK NC' : 72},
{'CENTRAL ALAMEDA NC' : 21},
{'CENTRAL HOLLYWOOD NC' : 27},
{'CENTRAL SAN PEDRO NC' : 48},
{'CHATSWORTH NC' : 96},
{'CHATSWORTH NC' : 107},
{'COASTAL SAN PEDRO NC' : 101},
{'COMMUNITY AND NEIGHBORS FOR NINTH DISTRICT UNITY (CANNDU)' : 33},
{'DOWNTOWN LOS ANGELES' : 3},
{'DOWNTOWN LOS ANGELES' : 9},
{'DOWNTOWN LOS ANGELES' : 10},
{'DOWNTOWN LOS ANGELES' : 17},
{'EAGLE ROCK NC' : 42},
{'EAGLE ROCK NC' : 55},
{'EMPOWERMENT CONGRESS CENTRAL AREA NDC' : 66},
{'EMPOWERMENT CONGRESS NORTH AREA NDC' : 15},
{'EMPOWERMENT CONGRESS SOUTHEAST AREA NDC' : 64},
{'EMPOWERMENT CONGRESS WEST AREA NDC' : 94},
{'ENCINO NC' : 83},
{'FOOTHILL TRAILS DISTRICT NC' : 24},
{'FOOTHILL TRAILS DISTRICT NC' : 77},
{'GLASSELL PARK NC' : 50},
{'GRANADA HILLS NORTH NC' : 18},
{'GREATER CYPRESS PARK NC' : 44},
{'GREATER ECHO PARK ELYSIAN NC' : 20},
{'GREATER TOLUCA LAKE NC' : 86},
{'GREATER WILSHIRE NC' : 29},
{'HARBOR CITY NC' : 85},
{'HARBOR GATEWAY SOUTH NC' : 79},
{'HISTORIC CULTURAL NC' : 4},
{'HISTORIC HIGHLAND PARK NC' : 12},
{'HOLLYWOOD HILLS WEST NC' : 41},
{'HOLLYWOOD HILLS WEST NC' : 76},
{'HOLLYWOOD STUDIO DISTRICT NC' : 52},
{'HOLLYWOOD UNITED NC' : 82},
{'LA-32 NC' : 16},
{'LA-32 NC' : 47},
{'LAKE BALBOA NC' : 100},
{'LAKE BALBOA NC' : 114},
{'LINCOLN HEIGHTS NC' : 1},
{'LOS FELIZ NC' : 35},
{'MAR VISTA CC' : 62},
{'MID CITY NC' : 68},
{'MID CITY WEST CC' : 61},
{'MID-TOWN NORTH HOLLYWOOD NC' : 60},
{'MISSION HILLS NC' : 75},
{'NC WESTCHESTER/PLAYA' : 5},
{'NC WESTCHESTER/PLAYA' : 51},
{'NC WESTCHESTER/PLAYA' : 67},
{'NC WESTCHESTER/PLAYA' : 80},
{'NC WESTCHESTER/PLAYA' : 95},
{'NORTH HILLS WEST NC' : 87},
{'NORTH HOLLYWOOD NORTHEAST NC' : 89},
{'NORTHRIDGE SOUTH NC' : 103},
{'NORTHRIDGE WEST' : 70},
{'NORTHWEST SAN PEDRO NC' : 36},
{'PACOIMA NC' : 98},
{'PALMS NC' : 43},
{'PANORAMA CITY NC' : 81},
{'PICO UNION NC' : 13},
{'PORTER RANCH NC' : 8},
{'PORTER RANCH NC' : 28},
{'RAMPART VILLAGE NC' : 6},
{'RESEDA NC' : 73},
{'SHERMAN OAKS NC' : 88},
{'SHERMAN OAKS NC' : 99},
{'SHERMAN OAKS NC' : 102},
{'SILVER LAKE NC' : 56},
{'SOUTH CENTRAL NC' : 14},
{'SOUTH ROBERTSON NC' : 58},
{'STUDIO CITY NC' : 78},
{'STUDIO CITY NC' : 97},
{'SUNLAND-TUJUNGA NC' : 74},
{'SYLMAR NC' : 91},
{'TARZANA NC' : 93},
{'UNITED NEIGHBORHOODS OF THE HISTORIC ARLINGTON HEIGHTS, WEST ADAMS, AND JEFFERSON PARK COMMUNITY' : 26},
{'UNITED NEIGHBORHOODS OF THE HISTORIC ARLINGTON HEIGHTS, WEST ADAMS, AND JEFFERSON PARK COMMUNITY' : 34},
{'VAN NUYS NC' : 39},
{'VENICE NC' : 63},
{'VOICES OF 90037' : 46},
{'WATTS NC' : 65},
{'WEST HILLS NC' : 106},
{'WEST LOS ANGELES NC' : 59},
{'WESTLAKE SOUTH NC' : 11},
{'WESTSIDE NC' : 92},
{'WESTWOOD NC' : 37},
{'WESTWOOD NC' : 71},
{'WILMINGTON NC' : 38},
{'WILMINGTON NC' : 40},
{'WILMINGTON NC' : 49},
{'WILMINGTON NC' : 111},
{'WINNETKA NC' : 104},
{'WOODLAND HILLS-WARNER CENTER NC' : 84},
{'WOODLAND HILLS-WARNER CENTER NC' : 105}]

# %%
reverse_dict = {}
for position in dict_nc_fire_station:
    for key, value in position.items():
        reverse_dict[value] = key

# %%
with open('./assets/reverse_dict.pkl', 'wb') as f:
    pickle.dump(reverse_dict, f)
    
# We made sure to pickle out this file because we will need it

# %% [markdown]
# Using the reverse_dictionary file, we paired the fire-station department to its' respective Neighborhood Council for the fire-station geo-dataset.

# %%
fire['fs_cd'] = fire['fs_cd'].astype(int)
fire['nc_name'] = fire['fs_cd'].map(reverse_dict)
fire.head()
# Out:
#             x_coord      zip           y_coord suff_dir  fs_cd  \
# 0  6468261.23133615  90029.0  1853003.78836346              52
# 1   6474895.4099969  90004.0  1850557.76471221               6
# 2  6434222.00610764  90064.0  1838657.47355221              92
# 3   6473368.7929714  90044.0  1811143.98888113              57
# 4  6407434.92713597  91406.0  1892973.60442105             100
#
#            shp_addr sttype   stname    hseno               address pref_dir  \
# 0   Fire Station 52    AVE  MELROSE   4957.0     4957 MELROSE AVE.
# 1    Fire Station 6    AVE   VIRGIL    326.0    326 N. VIRGIL AVE.        N
# 2   Fire Station 92   BLVD     PICO  10556.0    10556 W. PICO BLVD        W
# 3   Fire Station 57    AVE  VERMONT   7800.0  7800 S. VERMONT AVE.        S
# 4  Fire Station 100    AVE   LOUISE   6751.0       6751 LOUISE AVE
#
#   deptname unitdesc                                      geometry  \
# 0     FIRE           POINT (-118.3084747856537 34.08375012794097)
# ...

# %%
fire.drop(columns=['zip', 'suff_dir', 'shp_addr','pref_dir','deptname', 'unitdesc'], inplace=True)
fire.isnull().sum()
# Out:
# x_coord     0
# y_coord     0
# fs_cd       0
# sttype      0
# stname      0
# hseno       0
# address     0
# geometry    0
# nc_name     8
# dtype: int64

# %%
fire.dropna(0, 'any', inplace=True)

# %%
fire.to_file("./data/New_fire_station.geojson", driver='GeoJSON')

# %% [markdown]
# This plot displays the different fire-stations, marked in red, scattered throughout the different Neighborhood Councils in the LA County using terrain tile format.

# %%
fire = fire.to_crs(epsg=3857)


import contextily as ctx

def add_basemap(ax, zoom, url='http://tile.stamen.com/terrain/tileZ/tileX/tileY.png'):
    xmin, xmax, ymin, ymax = ax.axis()
    basemap, extent = ctx.bounds2img(xmin, ymin, xmax, ymax, zoom=zoom, url=url)
    ax.imshow(basemap, extent=extent, interpolation='bilinear')
    # restore original x/y limits
    ax.axis((xmin, xmax, ymin, ymax))

# %%
ax = fire.plot(figsize=(30, 20), color='red')
add_basemap(ax, zoom=14)

# %% [markdown]
# This plot gives a better display for the locations of the fire-stations with the help from the markings of the major locations.

# %%
ax = fire.plot(figsize=(30, 20), color='red')
add_basemap(ax, zoom=11, url=ctx.sources.ST_TONER_LITE)
ax.set_axis_off()

# %% [markdown]
# Using the Neighborhood Council geospatial shapefiles, we are able to see the boundaries of the Neighborhood Councils in the LA County region.

# %%
# n_councils = geopandas.read_file('./data/neighborhood_councils.shp')
# n_councils.head()

# %%
n_councils = n_councils.to_crs(epsg=3857)


import contextily as ctx

def add_basemap(ax, zoom, url='http://tile.stamen.com/terrain/tileZ/tileX/tileY.png'):
    xmin, xmax, ymin, ymax = ax.axis()
    basemap, extent = ctx.bounds2img(xmin, ymin, xmax, ymax, zoom=zoom, url=url)
    ax.imshow(basemap, extent=extent, interpolation='bilinear')
    # restore original x/y limits
    ax.axis((xmin, xmax, ymin, ymax))

# %%
ax = n_councils.plot(figsize=(30, 20), alpha=0.5, edgecolor='red', label='NAME')
add_basemap(ax, zoom=11, url=ctx.sources.ST_TONER_LITE) 
ax.set_axis_off()

# %% [markdown]
# Unfortunately the data does not provide other Neighborhood Councils that incorporate the other parts of the LA County that are left out. Due to the lack of information and data, we will proceed with only these distinct N.Cs all shaded in its' own colors with 1 or more fire-stations in it. Throughout the scope of the project, we will analyze and do investigations only limited to these Neighborhood Councils and specific fire-station departments portrayed below.

# %% [markdown]
# <img src="../images/nc_color.png" alt="N.C" width="800"/>
#
# *Created via Tableau*

# %% [markdown]
# <img src="../images/label_1.png" alt="Fire Stations in NC" width="200"/>
# <img src="../images/label_2.png" alt="Fire Stations in NC" width="200"/>
# <img src="../images/label_3.png" alt="Fire Stations in NC" width="200"/>
